# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem import PandasTools
from rdkit.Chem import Draw
from rdkit.Chem import AllChem
smiles = []

mysmiles=Chem.SDMolSupplier("best.sdf")
#for mol in mysmiles:
    #themol=Chem.MolToSmiles(mol)
    #smiles.append(themol)
    
    
#df = pd.DataFrame({'SMILES':smiles})
#df['Mol Image'] = [Chem.MolFromSmiles(s) for s in df['SMILES']]

#PandasTools.SaveXlsxFromFrame(df, 'thebest.xlsx', molCol='Mol Image')

ms = [x for x in mysmiles if x is not None]
for m in ms: tmp=AllChem.Compute2DCoords(m)

# %%
img=Draw.MolsToGridImage(ms[33:64],molsPerRow=4,subImgSize=(200,200))

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=800x1600 at 0x7F8BAEFFA780>
